# %% [markdown]
# <a href="https://colab.research.google.com/github/eugeniaring/machine-learning-course-eugenia/blob/main/lezione2_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Series vs Dataframe

# %% [markdown]
# ## passare dizionare per creare un dataframe

# %%
import pandas as pd

# %%
diz = {'titolo_film':['Barbie','Oppenheimer','Assassinio a Venezia'],'stars':[6,10,7]}
df = pd.DataFrame(diz)
df
# Out:
#             titolo_film  stars
# 0                Barbie      6
# 1           Oppenheimer     10
# 2  Assassinio a Venezia      7

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['titolo_film']
# Out:
# 0                  Barbie
# 1             Oppenheimer
# 2    Assassinio a Venezia
# Name: titolo_film, dtype: object

# %%
type(df['titolo_film'])
# Out:
# pandas.core.series.Series

# %%
series = pd.Series(['Barbie','Oppenheimer','Assassinio a Venezia'])
print(series)
# Out:
# 0                  Barbie
# 1             Oppenheimer
# 2    Assassinio a Venezia
# dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## passare lista di dizionari per creare un dataframe

# %%
lista = [{'titolo_film':'Barbie','stars':6},{'titolo_film':'Oppenheimer','stars':10},{'titolo_film':'Assissinio a venezia','stars':6}]
df = pd.DataFrame(lista)
df
# Out:
#             titolo_film  stars
# 0                Barbie      6
# 1           Oppenheimer     10
# 2  Assissinio a venezia      6

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame([1,2,3,4],columns=['stars'],index=['barbie','oppenheimer','assissinio a venezia','assissinio a New York'])
df
# Out:
#                        stars
# barbie                     1
# oppenheimer                2
# assissinio a venezia       3
# assissinio a New York      4

# %%
df.head()
# Out:
#    stars
# 0      1
# 1      2
# 2      3
# 3      4

# %%
df['stars']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: stars, dtype: int64

# %%
series = pd.Series([1,2,3,4])
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
series.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ## caricare file

# %%
df = pd.read_csv('books.csv',sep=',')
df
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# ...                                                  ...
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31282                                   SOL DE PLATA, EL
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)
#
#                                              description  \
# 0      Juramentada es la aclamada continuación deEl c...
# 1      Por la autora de diversos best sellers, V.E. S...
# 2      Reeditamos la clásica serie de fantasía La Rue...
# ...

# %% [markdown]
# ## EDA

# %%
df.head(3)
# Out:
#                                               title  \
# 0  JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                  LA VIDA INVISIBLE DE ADDIE LARUE
# 2       EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# 1        504           UMBRIEL  9788416517374          2020   06/10/2020
# 2        832         MINOTAURO  9788445007006          2019   15/10/2019
#
#               writer                                              image
# 0  Brandon Sanderson  https://imagessl0.casadellibro.com/a/l/t5/00/9...
# ...

# %%
df.tail()
# Out:
#                                                    title  \
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31282                                   SOL DE PLATA, EL
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)
#
#                                              description  \
# 31279  Mary Shelley (1797–1851) publicó“Frankenstein”...
# 31280  T has imaginat alguna vegada que la persona a ...
# 31281  Publicado originalmente en 1974 en la revista ...
# 31282                                                NaN
# 31283  Decimocuarta edición de esta obra que nos narr...
#
#                              gender  num_pages         editorial  \
# 31279           Narrativa de terror        384  PLUTON EDICIONES
# 31280           Narrativa de terror        138   LA VOCAL DE LIS
# 31281  Narrativa de ciencia ficción         62           NORDICA
# ...

# %%
df.shape
# Out:
# (31284, 10)

# %%
df.columns
# Out:
# Index(['title', 'description', 'gender', 'num_pages', 'editorial', 'isbn',
#        'year_edition', 'date_edition', 'writer', 'image'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31284 entries, 0 to 31283
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         31284 non-null  object
#  1   description   23197 non-null  object
#  2   gender        31226 non-null  object
#  3   num_pages     31284 non-null  int64
#  4   editorial     15307 non-null  object
#  5   isbn          31246 non-null  object
#  6   year_edition  31284 non-null  int64
#  7   date_edition  13123 non-null  object
#  8   writer        9150 non-null   object
#  9   image         31246 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#           num_pages  year_edition
# count  31284.000000  31284.000000
# mean     150.810478    938.972062
# std      219.052034   1004.282652
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%      272.000000   2011.000000
# max    10080.000000   9999.000000

# %%
df[df.num_pages<2000].boxplot(column='num_pages')
# Out:
# <Axes: >

# %%
df = pd.read_json('books.json')
df
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# ...                                                  ...
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31282                                   SOL DE PLATA, EL
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)
#
#                                              description  \
# 0      Juramentada es la aclamada continuación deEl c...
# 1      Por la autora de diversos best sellers, V.E. S...
# 2      Reeditamos la clásica serie de fantasía La Rue...
# ...

# %%
df = pd.read_excel('books.xlsx',sheet_name='Sheet1')
df.head(2)
# Out:
#                                               title  \
# 0  JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                  LA VIDA INVISIBLE DE ADDIE LARUE
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# 1        504           UMBRIEL  9788416517374          2020   06/10/2020
#
#               writer                                              image
# 0  Brandon Sanderson  https://imagessl0.casadellibro.com/a/l/t5/00/9...
# 1        V.e. Schwab  https://imagessl4.casadellibro.com/a/l/t5/74/9...

# %%
df['description'][:3]
# Out:
# 0    Juramentada es la aclamada continuación deEl c...
# 1    Por la autora de diversos best sellers, V.E. S...
# 2    Reeditamos la clásica serie de fantasía La Rue...
# Name: description, dtype: object

# %%
df['description'][-3:]
# Out:
# 31281    Publicado originalmente en 1974 en la revista ...
# 31282                                                  NaN
# 31283    Decimocuarta edición de esta obra que nos narr...
# Name: description, dtype: object

# %%
df.isnull()
# Out:
#        title  description  gender  num_pages  editorial   isbn  year_edition  \
# 0      False        False   False      False      False  False         False
# 1      False        False   False      False      False  False         False
# 2      False        False   False      False      False  False         False
# 3      False        False   False      False      False  False         False
# 4      False        False   False      False      False  False         False
# ...      ...          ...     ...        ...        ...    ...           ...
# 31279  False        False   False      False      False  False         False
# 31280  False        False   False      False      False  False         False
# 31281  False        False   False      False      False  False         False
# 31282  False         True   False      False      False  False         False
# 31283  False        False   False      False      False  False         False
#
#        date_edition  writer  image
# ...

# %%
df.isnull().sum()
# Out:
# title               0
# description      8087
# gender             58
# num_pages           0
# editorial       15977
# isbn               38
# year_edition        0
# date_edition    18161
# writer          22134
# image              38
# dtype: int64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# Narrativa fantástica                         0.309710
# Narrativa de ciencia ficción                 0.258535
# Narrativa de viajes                          0.231089
# Narrativa de terror                          0.111574
# Narrativa de humor                           0.088420
# Literatura en ingles                         0.000256
# Literatura en francés                        0.000128
# Narrativa extranjera hasta el siglo XVIII    0.000096
# Cuentos populares                            0.000064
# Terror en bolsillo                           0.000032
# Literatura 10 a 12 años                      0.000032
# Historia de los países de África             0.000032
# Fantasía y magia                             0.000032
# Name: gender, dtype: float64

# %%
df['gender'].value_counts(normalize=True)*100
# Out:
# Narrativa fantástica                         30.970986
# Narrativa de ciencia ficción                 25.853455
# Narrativa de viajes                          23.108948
# Narrativa de terror                          11.157369
# Narrativa de humor                            8.841991
# Literatura en ingles                          0.025620
# Literatura en francés                         0.012810
# Narrativa extranjera hasta el siglo XVIII     0.009607
# Cuentos populares                             0.006405
# Terror en bolsillo                            0.003202
# Literatura 10 a 12 años                       0.003202
# Historia de los países de África              0.003202
# Fantasía y magia                              0.003202
# Name: gender, dtype: float64

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df['title'][0]
# Out:
# 'JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)'

# %% [markdown]
# ## loc Vs iloc

# %%
df.iloc[0,0]
# Out:
# 'JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)'

# %%
df.loc[0,'title']
# Out:
# 'JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)'

# %%
df.set_index('title',inplace=True)

# %%
df.iloc[0,0]

# %%
df.loc['JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)','description']

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df.drop(['image'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df[['title','description']]
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# ...                                                  ...
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31282                                   SOL DE PLATA, EL
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)
#
#                                              description
# 0      Juramentada es la aclamada continuación deEl c...
# 1      Por la autora de diversos best sellers, V.E. S...
# 2      Reeditamos la clásica serie de fantasía La Rue...
# ...

# %%
df.loc[0:10,['title','description']]
# Out:
#                                                 title  \
# 0    JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                    LA VIDA INVISIBLE DE ADDIE LARUE
# 2         EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                EL MAPA DE LAS ISLAS
# 4   ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# 5                               LA FRONTERA INVISIBLE
# 6                       ESCUADRON CIELO: LA COLECCION
# 7   EL IMPERIO FINAL (NACIDOS DE LA BRUMA-MISTBORN...
# 8                          ENHORABUENA POR TU FRACASO
# 9     MONA LISA ACELERADA Nº 03/03 TRILOGIA DE SPRAWL
# 10  CRONICAS DE LA DRAGONLANCE Nº 01/03 EL RETORNO...
#
#                                           description
# 0   Juramentada es la aclamada continuación deEl c...
# 1   Por la autora de diversos best sellers, V.E. S...
# 2   Reeditamos la clásica serie de fantasía La Rue...
# 3   Las islas esconden tesoros. Las islas son para...
# ...

# %%
df.iloc[0:10,[0,1]]
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# 5                              LA FRONTERA INVISIBLE
# 6                      ESCUADRON CIELO: LA COLECCION
# 7  EL IMPERIO FINAL (NACIDOS DE LA BRUMA-MISTBORN...
# 8                         ENHORABUENA POR TU FRACASO
# 9    MONA LISA ACELERADA Nº 03/03 TRILOGIA DE SPRAWL
#
#                                          description
# 0  Juramentada es la aclamada continuación deEl c...
# 1  Por la autora de diversos best sellers, V.E. S...
# 2  Reeditamos la clásica serie de fantasía La Rue...
# 3  Las islas esconden tesoros. Las islas son para...
# 4  Consigue un ejemplar firmado por el autor y fr...
# 5  El último viaje de Javier Reverte ¿Dónde se en...
# ...

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df.loc[df['title']=='EL MAPA DE LAS ISLAS',['description','gender']]
# Out:
#                                          description               gender
# 3  Las islas esconden tesoros. Las islas son para...  Narrativa de viajes

# %%
df[df['title'].str.startswith('EL')]
# Out:
#                                                    title  \
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 7      EL IMPERIO FINAL (NACIDOS DE LA BRUMA-MISTBORN...
# 12     EL HEROE DE LAS ERAS (SAGA NACIDOS DE LA BRUMA 3)
# 14     EL HEROE DE LAS ERAS (NACIDOS DE LA BRUMA-MIST...
# ...                                                  ...
# 31271  EL ANGEL DE LAS TORMENTAS (TRILOGIA LA LEY DEL...
# 31274                   EL FANTASMA DE LA OPERA (2ª ED.)
# 31276  EL AÑO DE LA PURIFICACION (LA ESPADA DE LA VER...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
#
#                                              description  \
# 2      Reeditamos la clásica serie de fantasía La Rue...
# 3      Las islas esconden tesoros. Las islas son para...
# 7      Nueva edición deEl Imperio Final. El primer vo...
# ...

# %%
df[df['title'].str.contains('EL')]
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# 6                          ESCUADRON CIELO: LA COLECCION
# ...                                                  ...
# 31276  EL AÑO DE LA PURIFICACION (LA ESPADA DE LA VER...
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31282                                   SOL DE PLATA, EL
#
#                                              description  \
# 0      Juramentada es la aclamada continuación deEl c...
# 2      Reeditamos la clásica serie de fantasía La Rue...
# 3      Las islas esconden tesoros. Las islas son para...
# ...

# %%
df[df['title'].str.endswith('EL')]
# Out:
#                                               title  \
# 626                             DEATHS BRIGHT ANGEL
# 733                                         FLANNEL
# 802                             THE LORD OF STARIEL
# 890                                  LUCIFERS ANGEL
# 1051                                 WALKING ISRAEL
# ...                                             ...
# 30472                             LA HORA DEL ANGEL
# 30521  CHICAGO O UNA IMMERSIO AL BRESSOL DEL GOSPEL
# 31108                                     MONJE, EL
# 31112     CATALAN Y LOS SIETE PECADOS CAPITALES, EL
# 31282                              SOL DE PLATA, EL
#
#                                              description  \
# 626    Winner of the Crime Writers Associations John ...
# 733    Flannel is a story about a man - hardly a man ...
# 802    The Lord of Stariel is dead. Long live the Lor...
# 890    Sarah turns to witchcraft to console her griev...
# ...

# %%
df.isnull().sum()
# Out:
# title               0
# description      8087
# gender             58
# num_pages           0
# editorial       15977
# isbn               38
# year_edition        0
# date_edition    18161
# writer          22134
# dtype: int64

# %%
df['gender'].isnull().sum()/len(df)*100
# Out:
# 0.18539828666410946

# %%
df.dropna(subset='gender',inplace=True)

# %%
df['gender'].isnull().sum()/len(df)*100
# Out:
# 0.0

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df.loc[df.description.isnull(),'description'] = 'missing'

# %%
df['description'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['num_pages']<=100,['title','num_pages']]
# Out:
#                                                    title  num_pages
# 79                          QUIENES SE MARCHAN DE OMELAS         48
# 148                                      EN TU PUTA VIDA         90
# 165            LA LLAMADA DE CTHULHU (EDICION ILUSTRADA)         96
# 173    SLEEPY HOLLOW. LA LEYENDA DEL JINETE SIN CABEZ...         92
# 195               NOVISIMAS AVENTURAS DE SHERLOCK HOLMES         96
# ...                                                  ...        ...
# 31185                           LA TIERRA DE LOS SHERPAS         88
# 31198                                          LA HABANA         88
# 31246                                         CHIN MUSIC         88
# 31269            EN LA TIERRA DE LOS SANTOS Y LOS POETAS         96
# 31281                      EL DIA ANTES DE LA REVOLUCION         62
#
# [17085 rows x 2 columns]

# %%
df[(df['num_pages']>=50) & (df['num_pages']<=100)]
# Out:
#                                                    title  \
# 148                                      EN TU PUTA VIDA
# 165            LA LLAMADA DE CTHULHU (EDICION ILUSTRADA)
# 173    SLEEPY HOLLOW. LA LEYENDA DEL JINETE SIN CABEZ...
# 195               NOVISIMAS AVENTURAS DE SHERLOCK HOLMES
# 201       LOS 38 ASESINATOS Y MEDIO DEL CASTILLO DE HULL
# ...                                                  ...
# 31185                           LA TIERRA DE LOS SHERPAS
# 31198                                          LA HABANA
# 31246                                         CHIN MUSIC
# 31269            EN LA TIERRA DE LOS SANTOS Y LOS POETAS
# 31281                      EL DIA ANTES DE LA REVOLUCION
#
#                                              description  \
# 148    En tu puta vida también se podía haber titulad...
# 165    H. P. Lovecraft ha pasado a la historia de la ...
# 173    En el seno de una de esas colosales ensenadas ...
# ...

# %%
# libri che hanno meno di 50 pagine e più di 100 pagine
df.loc[(df['num_pages']<50) | (df['num_pages']>100),['title','num_pages']]
# Out:
#                                                    title  num_pages
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)       1408
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE        504
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)        832
# 3                                   EL MAPA DE LAS ISLAS        256
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...        224
# ...                                                  ...        ...
# 31278               UNDERWORLD (SAGA ASSASSIN S CREED 8)        424
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...        384
# 31280                    ELS TERRORS NOSTRES DE CADA DIA        138
# 31282                                   SOL DE PLATA, EL        304
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)        300
#
# [30647 rows x 2 columns]

# %%
df.loc[ df['num_pages'] < 100,['title','num_pages','editorial']]
# Out:
#                                                    title  num_pages  \
# 79                          QUIENES SE MARCHAN DE OMELAS         48
# 148                                      EN TU PUTA VIDA         90
# 165            LA LLAMADA DE CTHULHU (EDICION ILUSTRADA)         96
# 173    SLEEPY HOLLOW. LA LEYENDA DEL JINETE SIN CABEZ...         92
# 195               NOVISIMAS AVENTURAS DE SHERLOCK HOLMES         96
# ...                                                  ...        ...
# 31185                           LA TIERRA DE LOS SHERPAS         88
# 31198                                          LA HABANA         88
# 31246                                         CHIN MUSIC         88
# 31269            EN LA TIERRA DE LOS SANTOS Y LOS POETAS         96
# 31281                      EL DIA ANTES DE LA REVOLUCION         62
#
#                      editorial
# 79                     NORDICA
# 148    GRUPO LANTIA PUBLISHING
# 165                ALMA EUROPA
# ...

# %%
df[df['num_pages']>1000]
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 18     EL RITMO DE LA GUERRA (EL ARCHIVO DE LAS TORME...
# 27     EL ASCENSO DE LA SOMBRA (LA RUEDA DEL TIEMPO N...
# 66     EL SEÑOR DE LOS ANILLOS (NE). ILUSTRADO POR AL...
# 73     EL TEMOR DE UN HOMBRE SABIO (SAGA CRONICA DEL ...
# ...                                                  ...
# 31049                     GOTREK Y FELIX. PRIMER OMNIBUS
# 31111  EL SEÑOR DE LOS ANILLOS (EDICION LUJO. ILUSTRA...
# 31132  OMNIBUS ULTRAMARINES (PRIMERA TRILOGIA) (EL PO...
# 31136  OMNIBUS ULTRAMARINES (SEGUNDA TRILOGIA) (CAMPO...
# 31170                                          EISENHORN
#
#                                              description  \
# 0      Juramentada es la aclamada continuación deEl c...
# 18     El Ritmo de la Guerraes la esperada cuarta par...
# 27     Una de las obras maestras de la FantasíaLos se...
# ...

# %% [markdown]
# ## Ordinare i dati

# %%
df.sort_values(by='num_pages',ascending=False).head()
# Out:
#                                                    title  \
# 27285                                          TODO WILT
# 29166                                          TODO WILT
# 5702   PACK SAGA ASSASSIN S CREED (INCLUYE LOS 7 PRIM...
# 7662   EL SEÑOR DE LOS ANILLOS. EDICION ESPECIAL 60 A...
# 6461           ESTUCHE TOLKIEN 6 VOLS. + MAPA + POSTALES
#
#                                              description  \
# 27285  En 1976 Tom Sharpe creó a Henry Wilt, uno de l...
# 29166  En 1976 Tom Sharpe creó a Henry Wilt, uno de l...
# 5702   Por fin las siete primeras novelas de Assassin...
# 7662   Con motivo del 60 aniversario de la publicació...
# 6461   Las obras más representativas del autor, junta...
#
#                      gender  num_pages                editorial  \
# 27285    Narrativa de humor      10080                 ANAGRAMA
# 29166    Narrativa de humor      10080                 ANAGRAMA
# 5702   Narrativa fantástica       2852  LA ESFERA DE LOS LIBROS
# ...

# %%
df[['title','year_edition']].sort_values(by='year_edition',ascending=False).head()
# Out:
#                                                    title  year_edition
# 31111  EL SEÑOR DE LOS ANILLOS (EDICION LUJO. ILUSTRA...          9999
# 29943                                    EL LIBRO DEL YO          2093
# 28077                                    EL LIBRO DEL YO          2093
# 24479             ADONDE VAMOS NO NECESITAMOS CARRETERAS          2022
# 22175          (I.B.D.) HEROES, VIAJEROS, DIOSES Y REYES          2022

# %% [markdown]
# ## filtrare i dati

# %%
df[df['year_edition']==9999]
# Out:
#                                                    title  \
# 31111  EL SEÑOR DE LOS ANILLOS (EDICION LUJO. ILUSTRA...
#
#                                              description  \
# 31111  Esta edición contiene cincuenta ilustraciones ...
#
#                      gender  num_pages  editorial           isbn  \
# 31111  Narrativa fantástica       1272  MINOTAURO  9788445071793
#
#        year_edition date_edition          writer
# 31111          9999   20/06/2002  J.r.r. Tolkien

# %%
df = df[df['year_edition']!=9999]

# %%
df[df['year_edition']==9999]
# Out:
# Empty DataFrame
# Columns: [title, description, gender, num_pages, editorial, isbn, year_edition, date_edition, writer]
# Index: []

# %%
df['subtitle'] = 'ciao'
# Out:
# <ipython-input-112-86526f0cde90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['subtitle'] = 'ciao'

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   05/04/2018
# ...

# %%
df['subtitle'].value_counts()
# Out:
# ciao    31225
# Name: subtitle, dtype: int64

# %%
df['first_letters_title']  = df['title'].str[-3:]
# Out:
# <ipython-input-117-76a3fe6dd513>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first_letters_title']  = df['title'].str[-3:]

# %%
df[['title','first_letters_title']]
# Out:
#                                                    title first_letters_title
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)                  3)
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE                 RUE
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)                  1)
# 3                                   EL MAPA DE LAS ISLAS                 LAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...                 OR)
# ...                                                  ...                 ...
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...                 ES)
# 31280                    ELS TERRORS NOSTRES DE CADA DIA                 DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION                 ION
# 31282                                   SOL DE PLATA, EL                  EL
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)                 D.)
#
# [31225 rows x 2 columns]

# %% [markdown]
# ## raggruppare i dati

# %%
df.groupby(by='gender').num_pages.mean().reset_index()
# Out:
#                                        gender   num_pages
# 0                           Cuentos populares  240.000000
# 1                            Fantasía y magia  600.000000
# 2            Historia de los países de África  396.000000
# 3                     Literatura 10 a 12 años  346.000000
# 4                       Literatura en francés  187.500000
# 5                        Literatura en ingles  202.875000
# 6                Narrativa de ciencia ficción  145.588753
# 7                          Narrativa de humor  112.056139
# 8                         Narrativa de terror  181.136338
# 9                         Narrativa de viajes  133.021203
# 10  Narrativa extranjera hasta el siglo XVIII  324.000000
# 11                       Narrativa fantástica  168.652120
# 12                         Terror en bolsillo  448.000000

# %%
df.groupby(by='gender').groups
# Out:
# {'Cuentos populares': [27744, 29667], 'Fantasía y magia': [30143], 'Historia de los países de África': [7718], 'Literatura 10 a 12 años': [4241], 'Literatura en francés': [338, 343, 347, 349], 'Literatura en ingles': [3642, 4419, 4721, 4761, 4762, 4843, 4882, 20871], 'Narrativa de ciencia ficción': [6, 9, 17, 19, 29, 30, 32, 34, 39, 52, 55, 57, 58, 60, 61, 65, 79, 82, 88, 95, 105, 112, 125, 126, 129, 131, 139, 152, 154, 156, 158, 159, 161, 166, 167, 169, 170, 176, 177, 181, 182, 189, 190, 193, 207, 212, 213, 216, 217, 228, 229, 233, 236, 240, 242, 250, 257, 258, 261, 262, 267, 271, 276, 277, 280, 287, 292, 295, 299, 301, 302, 305, 307, 314, 315, 316, 317, 318, 322, 323, 327, 364, 368, 385, 392, 396, 400, 401, 407, 408, 409, 410, 413, 449, 453, 457, 466, 481, 491, 514, ...], 'Narrativa de humor': [4, 8, 25, 40, 54, 69, 80, 96, 106, 108, 109, 128, 140, 145, 148, 178, 183, 195, 201, 219, 226, 227, 259, 309, 330, 359, 363, 369, 387, 390, 415, 421, 423, 425, 429, 436, 440, 444, 456, 461, 
# ...

# %%
df_sch = df.groupby('gender').num_pages.max()
df_sch
# Out:
# gender
# Cuentos populares                              240
# Fantasía y magia                               600
# Historia de los países de África               396
# Literatura 10 a 12 años                        346
# Literatura en francés                          308
# Literatura en ingles                           487
# Narrativa de ciencia ficción                  1744
# Narrativa de humor                           10080
# Narrativa de terror                           1704
# Narrativa de viajes                           1684
# Narrativa extranjera hasta el siglo XVIII      456
# Narrativa fantástica                          2852
# Terror en bolsillo                             448
# Name: num_pages, dtype: int64

# %%
df_sch.index
# Out:
# Index(['Cuentos populares', 'Fantasía y magia',
#        'Historia de los países de África', 'Literatura 10 a 12 años',
#        'Literatura en francés', 'Literatura en ingles',
#        'Narrativa de ciencia ficción', 'Narrativa de humor',
#        'Narrativa de terror', 'Narrativa de viajes',
#        'Narrativa extranjera hasta el siglo XVIII', 'Narrativa fantástica',
#        'Terror en bolsillo'],
#       dtype='object', name='gender')

# %%
df_sch = df.groupby('gender').num_pages.max().reset_index().sort_values('num_pages',ascending=False).reset_index(drop='index')

# %%
df_sch
# Out:
#                                        gender  num_pages
# 0                          Narrativa de humor      10080
# 1                        Narrativa fantástica       2852
# 2                Narrativa de ciencia ficción       1744
# 3                         Narrativa de terror       1704
# 4                         Narrativa de viajes       1684
# 5                            Fantasía y magia        600
# 6                        Literatura en ingles        487
# 7   Narrativa extranjera hasta el siglo XVIII        456
# 8                          Terror en bolsillo        448
# 9            Historia de los países de África        396
# 10                    Literatura 10 a 12 años        346
# 11                      Literatura en francés        308
# 12                          Cuentos populares        240

# %%
type(df_sch)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sch['num_pages']
# Out:
# 0       240
# 1       600
# 2       396
# 3       346
# 4       308
# 5       487
# 6      1744
# 7     10080
# 8      1704
# 9      1684
# 10      456
# 11     2852
# 12      448
# Name: num_pages, dtype: int64

# %%
df.groupby('gender').num_pages.max().reset_index().sort_values(by='num_pages',ascending=False)
# Out:
#                                        gender  num_pages
# 7                          Narrativa de humor      10080
# 11                       Narrativa fantástica       2852
# 6                Narrativa de ciencia ficción       1744
# 8                         Narrativa de terror       1704
# 9                         Narrativa de viajes       1684
# 1                            Fantasía y magia        600
# 5                        Literatura en ingles        487
# 10  Narrativa extranjera hasta el siglo XVIII        456
# 12                         Terror en bolsillo        448
# 2            Historia de los países de África        396
# 3                     Literatura 10 a 12 años        346
# 4                       Literatura en francés        308
# 0                           Cuentos populares        240

# %%
df.groupby('gender').agg( { 'num_pages':['count','min','max','mean'],'year_edition':['min','max'] } )
# Out:
#                                           num_pages                          \
#                                               count  min    max        mean
# gender
# Cuentos populares                                 2  240    240  240.000000
# Fantasía y magia                                  1  600    600  600.000000
# Historia de los países de África                  1  396    396  396.000000
# Literatura 10 a 12 años                           1  346    346  346.000000
# Literatura en francés                             4    0    308  187.500000
# Literatura en ingles                              8    0    487  202.875000
# Narrativa de ciencia ficción                   8073    0   1744  145.588753
# Narrativa de humor                             2761    0  10080  112.056139
# Narrativa de terror                            3484    0   1704  181.136338
# Narrativa de viajes                            7216    0   1684  133.021203
# ...

# %%
df[df['year_edition']==0]
# Out:
#                                                    title  \
# 330                       NOUVEAU PT LIV LIRE AUX TOILET
# 334    LES PLUS BEAUX VOYAGES EN BATEAU 25 CROISIERES...
# 365                            LA TORRE DE LA GOLONDRINA
# 366                  CHORO 2021. UNA DISTOPA BOLIVARIANA
# 367                        EL MISTERIO DE ABI II. ORIGEN
# ...                                                  ...
# 30990  LA VUELTA AL MUNDO EN 10 AÑOS: EL LIBRO DE LA ...
# 31081                                GRAVE DANS LE SABLE
# 31116                                            NEMESIS
# 31121                              EL PACTO DE LA CORONA
# 31123                          LA EDAD DEL FUTUO. TOMO 1
#
#                                              description  \
# 330    De nombreuses cartes et un plan d??tachable po...
# 334    Un voyage ?? bord des plus beaux longs-courrie...
# 365    ?Puedo darte todo lo que desees ?dijo el hada?...
# ...

# %% [markdown]
# ## Date

# %%
df['date_edition']
# Out:
# 0        05/04/2018
# 1        06/10/2020
# 2        15/10/2019
# 3        18/05/2022
# 4        09/06/2022
#             ...
# 31279    25/02/2017
# 31280    30/11/2016
# 31281    09/12/2016
# 31282           NaN
# 31283    09/06/2008
# Name: date_edition, Length: 31225, dtype: object

# %%
type(df['date_edition'][0])
# Out:
# str

# %%
df['date_edition'] = pd.to_datetime(df['date_edition'])
# Out:
# <ipython-input-204-73fab1a6674a>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date_edition'] = pd.to_datetime(df['date_edition'])

# %%
type(df['date_edition'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['date_edition'].head()
# Out:
# 0   2018-05-04
# 1   2020-06-10
# 2   2019-10-15
# 3   2022-05-18
# 4   2022-09-06
# Name: date_edition, dtype: datetime64[ns]

# %%
df['date_edition'].dt.day.head()
# Out:
# 0     4.0
# 1    10.0
# 2    15.0
# 3    18.0
# 4     6.0
# Name: date_edition, dtype: float64

# %%
df['date_edition'].dt.month.head()
# Out:
# 0     5.0
# 1     6.0
# 2    10.0
# 3     5.0
# 4     9.0
# Name: date_edition, dtype: float64

# %%
df['month_edition'] = df['date_edition'].dt.month

# %%
df[['month_edition','date_edition']]
# Out:
#        month_edition date_edition
# 0                5.0   2018-05-04
# 1                6.0   2020-06-10
# 2               10.0   2019-10-15
# 3                5.0   2022-05-18
# 4                9.0   2022-09-06
# ...              ...          ...
# 31279            2.0   2017-02-25
# 31280           11.0   2016-11-30
# 31281            9.0   2016-09-12
# 31282            NaN          NaT
# 31283            9.0   2008-09-06
#
# [31225 rows x 2 columns]

# %%
type(df['month_edition'][0])
# Out:
# numpy.float64

# %%
df[df['month_edition'].isnull()==False]
# Out:
#                                                    title  \
# 0       JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                       LA VIDA INVISIBLE DE ADDIE LARUE
# 2            EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                                   EL MAPA DE LAS ISLAS
# 4      ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
# ...                                                  ...
# 31278               UNDERWORLD (SAGA ASSASSIN S CREED 8)
# 31279  FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280                    ELS TERRORS NOSTRES DE CADA DIA
# 31281                      EL DIA ANTES DE LA REVOLUCION
# 31283           LA EXPEDICION DE LA "KON-TIKI" (15ª ED.)
#
#                                              description  \
# 0      Juramentada es la aclamada continuación deEl c...
# 1      Por la autora de diversos best sellers, V.E. S...
# 2      Reeditamos la clásica serie de fantasía La Rue...
# ...

# %%
import numpy as np

# %%
df.loc[df['month_edition'].isnull()==False,'month_edition'].astype('int')
# Out:
# 0         5
# 1         6
# 2        10
# 3         5
# 4         9
#          ..
# 31278     7
# 31279     2
# 31280    11
# 31281     9
# 31283     9
# Name: month_edition, Length: 13109, dtype: int64

# %%
df.loc[df['month_edition'].isnull()==False,'month_edition'] = df.loc[df['month_edition'].isnull()==False,'month_edition'].astype(np.int64)

# %%
df[['month_edition','date_edition']]
# Out:
#        month_edition date_edition
# 0                5.0   2018-05-04
# 1                6.0   2020-06-10
# 2               10.0   2019-10-15
# 3                5.0   2022-05-18
# 4                9.0   2022-09-06
# ...              ...          ...
# 31279            2.0   2017-02-25
# 31280           11.0   2016-11-30
# 31281            9.0   2016-09-12
# 31282            NaN          NaT
# 31283            9.0   2008-09-06
#
# [31225 rows x 2 columns]

# %%
df.head()
# Out:
#                                                title  \
# 0   JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS 3)
# 1                   LA VIDA INVISIBLE DE ADDIE LARUE
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1)
# 3                               EL MAPA DE LAS ISLAS
# 4  ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#
#                                          description                gender  \
# 0  Juramentada es la aclamada continuación deEl c...  Narrativa fantástica
# 1  Por la autora de diversos best sellers, V.E. S...  Narrativa fantástica
# 2  Reeditamos la clásica serie de fantasía La Rue...  Narrativa fantástica
# 3  Las islas esconden tesoros. Las islas son para...   Narrativa de viajes
# 4  Consigue un ejemplar firmado por el autor y fr...    Narrativa de humor
#
#    num_pages         editorial           isbn  year_edition date_edition  \
# 0       1408  S.A. EDICIONES B  9788417347000          2018   2018-05-04
# ...

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-185-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df[df['description'].isdi
# Out:
# 0        Juramentada es la aclamada continuación deEl c...
# 1        Por la autora de diversos best sellers, V.E. S...
# 2        Reeditamos la clásica serie de fantasía La Rue...
# 3        Las islas esconden tesoros. Las islas son para...
# 4        Consigue un ejemplar firmado por el autor y fr...
#                                ...
# 31276    Con El año de la purificación Timun Mas alcanz...
# 31277    ¿Puede un restaurante ofrecer jamón, y melón, ...
# 31278    Basado en la exitosa serie de videojuegosEn 18...
# 31281    Publicado originalmente en 1974 en la revista ...
# 31283    Decimocuarta edición de esta obra que nos narr...
# Name: description, Length: 7994, dtype: object

# %%
import time

start = time.time()
df['all_content'] = df['title']+' '+ df['description']
df['all_content']
end = time.time()
print(end-start)
# Out:
# 0.0676577091217041

# %%
import time

start = time.time()
df['title']+' '+ df['description']
# Out:
# 0        JURAMENTADA (SAGA EL ARCHIVO DE LAS TORMENTAS ...
# 1        LA VIDA INVISIBLE DE ADDIE LARUE Por la autora...
# 2        EL OJO DEL MUNDO (LA RUEDA DEL TIEMPO Nº 1) Re...
# 3        EL MAPA DE LAS ISLAS Las islas esconden tesoro...
# 4        ENHORABUENA POR TU FRACASO (EJEMPLAR FIRMADO P...
#                                ...
# 31279    FRANKENSTEIN O EL MODERNO PROMETEO / FRANKENST...
# 31280    ELS TERRORS NOSTRES DE CADA DIA T has imaginat...
# 31281    EL DIA ANTES DE LA REVOLUCION Publicado origin...
# 31282                                                  NaN
# 31283    LA EXPEDICION DE LA "KON-TIKI" (15ª ED.) Decim...
# Length: 31284, dtype: object

# %% [markdown]
# ## visualizzare i dati

# %%
df['num_pages'].hist(bins=100)
# Out:
# <Axes: >

# %%
df.boxplot(column='num_pages')
# Out:
# <Axes: >

# %%
df['num_pages'].plot()
# Out:
# <Axes: >
