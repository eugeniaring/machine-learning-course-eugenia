# %% [markdown]
# <a href="https://colab.research.google.com/github/eugeniaring/machine-learning-course-eugenia/blob/main/geospatialdataanalysis_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_excel('ARIA_2021.xlsx',sheet_name='Tav.7.1 - aria',header=8,skipfooter=18)
df.tail(20)
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4
# 90               Matera          0          0         NaN         NaN
# 91              Cosenza         20          0         NaN         NaN
# 92              Crotone       12.5          0         NaN         NaN
# 93            Catanzaro          0          0         NaN         NaN
# 94        Vibo Valentia          0          0         NaN         NaN
# 95   Reggio di Calabria       12.5       12.5         NaN         NaN
# 96              Trapani          0          0         NaN         NaN
# 97              Palermo  22.222222        NaN         NaN         NaN
# 98              Messina          0          0         NaN         NaN
# 99            Agrigento         ….         ….         NaN         NaN
# 100       Caltanissetta          0          0         NaN         NaN
# 101                Enna         20         20         NaN         NaN
# ...

# %%
df.columns = ['citta','indice_aria_2020','indice_aria_2021','col1','col2']
df.head()
# Out:
#       citta indice_aria_2020 indice_aria_2021  col1  col2
# 0    Torino        66.666667        66.666667   NaN   NaN
# 1  Vercelli        44.444444        33.333333   NaN   NaN
# 2    Novara             37.5               25   NaN   NaN
# 3    Biella             12.5             12.5   NaN   NaN
# 4     Cuneo               20               40   NaN   NaN

# %%
df.drop(['col1','col2'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       citta indice_aria_2020 indice_aria_2021
# 0    Torino        66.666667        66.666667
# 1  Vercelli        44.444444        33.333333
# 2    Novara             37.5               25
# 3    Biella             12.5             12.5
# 4     Cuneo               20               40

# %%
df.describe()
# Out:
#          citta  indice_aria_2020  indice_aria_2021
# count      110               109               107
# unique     110                41                38
# top     Torino                 0                 0
# freq         1                23                28

# %%
df[df['citta']=='Torino']
# Out:
#     citta indice_aria_2020 indice_aria_2021
# 0  Torino        66.666667        66.666667

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   citta             110 non-null    object
#  1   indice_aria_2020  109 non-null    object
#  2   indice_aria_2021  107 non-null    object
# dtypes: object(3)
# memory usage: 2.7+ KB

# %%
df.tail(20)
# Out:
#                   citta indice_aria_2020 indice_aria_2021
# 90               Matera                0                0
# 91              Cosenza               20                0
# 92              Crotone             12.5                0
# 93            Catanzaro                0                0
# 94        Vibo Valentia                0                0
# 95   Reggio di Calabria             12.5             12.5
# 96              Trapani                0                0
# 97              Palermo        22.222222              NaN
# 98              Messina                0                0
# 99            Agrigento               ….               ….
# 100       Caltanissetta                0                0
# 101                Enna               20               20
# 102             Catania              NaN              NaN
# 103              Ragusa         9.090909        11.111111
# 104            Siracusa        11.764706        14.285714
# ...

# %%
df.indice_aria_2020.unique()
# Out:
# array([66.66666666666666, 44.44444444444444, 37.5, 12.5, 20, 50,
#        7.142857142857142, '….', 7.6923076923076925, 16, 0,
#        33.33333333333333, 60, 58.82352941176471, 55.55555555555556,
#        58.333333333333336, 42.857142857142854, 10, 25, 61.53846153846154,
#        48, 18.181818181818183, 6.25, 38.46153846153847, 47.05882352941176,
#        62.5, 22.22222222222222, 11.11111111111111, 14.285714285714285,
#        34.78260869565217, 21.311475409836063, 23.076923076923077,
#        16.666666666666664, 26.923076923076923, 10.526315789473683,
#        3.571428571428571, 3.8461538461538463, 8.333333333333332, nan,
#        9.090909090909092, 11.76470588235294, 13.333333333333334],
#       dtype=object)

# %%
df = df[df!='….']

# %%
df['indice_aria_2020'] = df['indice_aria_2020'].astype('float')
df['indice_aria_2021'] = df['indice_aria_2021'].astype('float')

# %%
df.head()
# Out:
#       citta  indice_aria_2020  indice_aria_2021
# 0    Torino         66.666667         66.666667
# 1  Vercelli         44.444444         33.333333
# 2    Novara         37.500000         25.000000
# 3    Biella         12.500000         12.500000
# 4     Cuneo         20.000000         40.000000

# %%
df.shape
# Out:
# (110, 3)

# %%
df.isnull().sum()
# Out:
# citta               0
# indice_aria_2020    7
# indice_aria_2021    9
# dtype: int64

# %%
df[df.indice_aria_2020.isnull()]
# Out:
#           citta  indice_aria_2020  indice_aria_2021
# 9       Imperia               NaN               NaN
# 63        Fermo               NaN               NaN
# 74      Isernia               NaN               NaN
# 75   Campobasso               NaN               NaN
# 84        Trani               NaN               NaN
# 99    Agrigento               NaN               NaN
# 102     Catania               NaN               NaN

# %%
df.dropna(subset=['indice_aria_2020','indice_aria_2021'],inplace=True)

# %%
df.isnull().sum()
# Out:
# citta               0
# indice_aria_2020    0
# indice_aria_2021    0
# dtype: int64
